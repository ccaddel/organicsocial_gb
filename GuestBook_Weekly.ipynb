# %% [markdown]
# ## Weekly Twitter, Facebook and Instagram Organic Data

# %%
import pandas as pd
import numpy as np
import datetime as dt
from time import strptime

# %% [markdown]
# ### Twitter
#
# Read in data export from twitter platform, wrangle, and export cleaned csv

# %%
# 11/2 - 11/8
twitter = pd.read_csv('tw_weekly_pull.csv')
print(twitter.info())
twitter.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 40 columns):
# Tweet id                        34 non-null float64
# Tweet permalink                 34 non-null object
# Tweet text                      34 non-null object
# time                            34 non-null object
# impressions                     34 non-null int64
# engagements                     34 non-null int64
# engagement rate                 34 non-null float64
# retweets                        34 non-null int64
# replies                         34 non-null int64
# likes                           34 non-null int64
# user profile clicks             34 non-null int64
# url clicks                      34 non-null int64
# hashtag clicks                  34 non-null int64
# detail expands                  34 non-null int64
# permalink clicks                34 non-null int64
# app opens                       34 non-null int64
# app installs                    34 non-null int64
# follows                         34 non-null int64
# email tweet                     34 non-null int64
# dial phone                      34 non-null int64
# media views                     34 non-null int64
# media engagements               34 non-null int64
# promoted impressions            34 non-null object
# promoted engagements            34 non-null object
# promoted engagement rate        34 non-null object
# promoted retweets               34 non-null object
# promoted replies                34 non-null object
# promoted likes                  34 non-null object
# promoted user profile clicks    34 non-null object
# promoted url clicks             34 non-null object
# promoted hashtag clicks         34 non-null object
# promoted detail expands         34 non-null object
# promoted permalink clicks       34 non-null object
# promoted app opens              34 non-null object
# promoted app installs           34 non-null object
# promoted follows                34 non-null object
# promoted email tweet            34 non-null object
# promoted dial phone             34 non-null object
# promoted media views            34 non-null object
# promoted media engagements      34 non-null object
# dtypes: float64(2), int64(17), object(21)
# memory usage: 10.7+ KB
# None
#        Tweet id                                    Tweet permalink  \
# 0  1.060680e+18  https://twitter.com/guestbooktbs/status/106068...
# 1  1.060620e+18  https://twitter.com/guestbooktbs/status/106061...
# 2  1.060300e+18  https://twitter.com/guestbooktbs/status/106029...
# 3  1.060020e+18  https://twitter.com/guestbooktbs/status/106001...
# 4  1.060020e+18  https://twitter.com/guestbooktbs/status/106001...
#
#                                           Tweet text                    time  \
# 0  Fact: diarrhea can't partake in no-shave Novem...  2018-11-08 23:48 +0000
# 1  Ecstasy. That is all. Catch up on #TheGuestBoo...  2018-11-08 19:28 +0000
# 2  Every vacation has a weird story, or two. So w...  2018-11-07 22:35 +0000
# 3  Keep an eye out for next week's episode of #Th...  2018-11-07 04:00 +0000
# 4  Damn it, Tim. That really came full-circle. 😭 ...  2018-11-07 03:58 +0000
#
#    impressions  engagements  engagement rate  retweets  replies  likes  \
# 0          542           31         0.057196         2        1     15
# 1          467           17         0.036403         2        1      8
# 2          535           18         0.033645         1        1      5
# 3         1084           78         0.071956         1        0     12
# 4          545           20         0.036697         0        0      8
#
#               ...              promoted hashtag clicks  \
# 0             ...                                    -
# 1             ...                                    -
# 2             ...                                    -
# 3             ...                                    -
# 4             ...                                    -
#
#    promoted detail expands  promoted permalink clicks  promoted app opens  \
# 0                        -                          -                   -
# 1                        -                          -                   -
# 2                        -                          -                   -
# 3                        -                          -                   -
# 4                        -                          -                   -
#
#    promoted app installs  promoted follows  promoted email tweet  \
# 0                      -                 -                     -
# 1                      -                 -                     -
# 2                      -                 -                     -
# 3                      -                 -                     -
# 4                      -                 -                     -
#
#    promoted dial phone  promoted media views  promoted media engagements
# 0                    -                     -                           -
# 1                    -                     -                           -
# 2                    -                     -                           -
# 3                    -                     -                           -
# 4                    -                     -                           -
#
# [5 rows x 40 columns]

# %%
# filter out unneeded columns
twitter = twitter.filter(['Tweet permalink', 'Tweet text', 'time', 'impressions','promoted impressions', 'engagements',
                          'engagement rate', 'retweets', 'replies', 'likes', 'media views', 'promoted media views','media engagements'])
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 13 columns):
# Tweet permalink         34 non-null object
# Tweet text              34 non-null object
# time                    34 non-null object
# impressions             34 non-null int64
# promoted impressions    34 non-null object
# engagements             34 non-null int64
# engagement rate         34 non-null float64
# retweets                34 non-null int64
# replies                 34 non-null int64
# likes                   34 non-null int64
# media views             34 non-null int64
# promoted media views    34 non-null object
# media engagements       34 non-null int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 3.5+ KB

# %%
#create 'post type' column indicating whether reply or original post
twitter['post type'] = twitter['Tweet text'].map(lambda x: "reply" if x[0] == '@' else "post")

# create 'vis eng' column calculating visible engagements by adding retweets, replies, likes
twitter['vis eng'] = twitter['retweets'] + twitter['replies'] + twitter['likes']

# create 'view Rate' and 'completion rate' columns by dividing media views and engagements by impressions, respectively
twitter['view rate'] = twitter['media views']/twitter['impressions']
twitter['completion rate'] = twitter['media engagements']/twitter['impressions']

# add 'episode' column assigning episode number: first 2 digits = season number, last 2 digits = episode number
twitter['episode'] = '204'

# convert 'date' column to datetime
twitter['time'] = pd.to_datetime(twitter['time'])

# create 'in-show' column - show aired on 11/6 10pm, so tweets between GMT (does NOT change for daylight savings)
# 11/7 2AM - 7AM are "in-show"
twitter['in-show'] = twitter['time'].map(lambda x: "in-show" if x >= pd.to_datetime(['2018-11-7 02:00:00']) and x <= pd.to_datetime(['2018-11-7 07:00:00']) else "not")

# create empty 'Votes' column
twitter['votes'] = np.nan

print(twitter.info())
twitter.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 20 columns):
# Tweet permalink         34 non-null object
# Tweet text              34 non-null object
# time                    34 non-null datetime64[ns]
# impressions             34 non-null int64
# promoted impressions    34 non-null object
# engagements             34 non-null int64
# engagement rate         34 non-null float64
# retweets                34 non-null int64
# replies                 34 non-null int64
# likes                   34 non-null int64
# media views             34 non-null int64
# promoted media views    34 non-null object
# media engagements       34 non-null int64
# post type               34 non-null object
# vis eng                 34 non-null int64
# view rate               34 non-null float64
# completion rate         34 non-null float64
# episode                 34 non-null object
# in-show                 34 non-null object
# votes                   0 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(7)
# memory usage: 5.4+ KB
# None
#                                      Tweet permalink  \
# 0  https://twitter.com/guestbooktbs/status/106068...
# 1  https://twitter.com/guestbooktbs/status/106061...
# 2  https://twitter.com/guestbooktbs/status/106029...
# 3  https://twitter.com/guestbooktbs/status/106001...
# 4  https://twitter.com/guestbooktbs/status/106001...
#
#                                           Tweet text                time  \
# 0  Fact: diarrhea can't partake in no-shave Novem... 2018-11-08 23:48:00
# 1  Ecstasy. That is all. Catch up on #TheGuestBoo... 2018-11-08 19:28:00
# 2  Every vacation has a weird story, or two. So w... 2018-11-07 22:35:00
# 3  Keep an eye out for next week's episode of #Th... 2018-11-07 04:00:00
# 4  Damn it, Tim. That really came full-circle. 😭 ... 2018-11-07 03:58:00
#
#    impressions promoted impressions  engagements  engagement rate  retweets  \
# 0          542                    -           31         0.057196         2
# 1          467                    -           17         0.036403         2
# 2          535                    -           18         0.033645         1
# 3         1084                    -           78         0.071956         1
# 4          545                    -           20         0.036697         0
#
#    replies  likes  media views promoted media views  media engagements  \
# 0        1     15          164                    -                 10
# 1        1      8           96                    -                  1
# 2        1      5           10                    -                 10
# 3        0     12          915                    -                 38
# 4        0      8          114                    -                  7
#
#   post type  vis eng  view rate  completion rate episode  in-show  votes
# 0      post       18   0.302583         0.018450     204      not    NaN
# 1      post       11   0.205567         0.002141     204      not    NaN
# 2      post        7   0.018692         0.018692     204      not    NaN
# 3      post       13   0.844096         0.035055     204  in-show    NaN
# 4      post        8   0.209174         0.012844     204  in-show    NaN

# %%
twitter['time'] = twitter['time'].dt.normalize()
print(twitter['time'].dtype)

#Phase = pre-premiere/premiere week/premiere day/continuity/finale/off season
twitter['phase'] = 'continuity'
#twitter['time'].map(lambda x: "premiere day" if x == pd.to_datetime(['2018-10-23 00:00:00']) else "premiere week")

twitter['messaging'] = twitter['Tweet text'].map(lambda x: "Premiere" if 'premiere' in x 
                                                 else "Tuesday" if 'Tues' in x else "Tuesday" if 'Tuesday' in x 
                                                 else "Tomorrow" if 'tomorrow' in x else "Tonight" if 'tonight' in x 
                                                 else "Tonight" if 'TONIGHT' in x else "On Demand" if 'on demand' in x
                                                 else "Tomorrow" if 'Tomorrow' in x else "Tonight" if 'Tonight' in x
                                                 else "Tonight" if 'TONIGHT' in x else "TBS App" if 'TBS App' in x else "Evergreen")

twitter
# Out:
# datetime64[ns]
#                                       Tweet permalink  \
# 0   https://twitter.com/guestbooktbs/status/106068...
# 1   https://twitter.com/guestbooktbs/status/106061...
# 2   https://twitter.com/guestbooktbs/status/106029...
# 3   https://twitter.com/guestbooktbs/status/106001...
# 4   https://twitter.com/guestbooktbs/status/106001...
# 5   https://twitter.com/guestbooktbs/status/106001...
# 6   https://twitter.com/guestbooktbs/status/106001...
# 7   https://twitter.com/guestbooktbs/status/106001...
# 8   https://twitter.com/guestbooktbs/status/106001...
# 9   https://twitter.com/guestbooktbs/status/106001...
# 10  https://twitter.com/guestbooktbs/status/106001...
# 11  https://twitter.com/guestbooktbs/status/106001...
# 12  https://twitter.com/guestbooktbs/status/106001...
# 13  https://twitter.com/guestbooktbs/status/106001...
# 14  https://twitter.com/guestbooktbs/status/106001...
# 15  https://twitter.com/guestbooktbs/status/106001...
# 16  https://twitter.com/guestbooktbs/status/106001...
# 17  https://twitter.com/guestbooktbs/status/106001...
# 18  https://twitter.com/guestbooktbs/status/106001...
# 19  https://twitter.com/guestbooktbs/status/106001...
# 20  https://twitter.com/guestbooktbs/status/106001...
# 21  https://twitter.com/guestbooktbs/status/106000...
# 22  https://twitter.com/guestbooktbs/status/105998...
# 23  https://twitter.com/guestbooktbs/status/105996...
# 24  https://twitter.com/guestbooktbs/status/105988...
# 25  https://twitter.com/guestbooktbs/status/105988...
# 26  https://twitter.com/guestbooktbs/status/105988...
# 27  https://twitter.com/guestbooktbs/status/105985...
# 28  https://twitter.com/guestbooktbs/status/105953...
# 29  https://twitter.com/guestbooktbs/status/105949...
# 30  https://twitter.com/guestbooktbs/status/105917...
# 31  https://twitter.com/guestbooktbs/status/105852...
# 32  https://twitter.com/guestbooktbs/status/105846...
# 33  https://twitter.com/guestbooktbs/status/105838...
#
#                                            Tweet text       time  impressions  \
# 0   Fact: diarrhea can't partake in no-shave Novem... 2018-11-08          542
# 1   Ecstasy. That is all. Catch up on #TheGuestBoo... 2018-11-08          467
# 2   Every vacation has a weird story, or two. So w... 2018-11-07          535
# 3   Keep an eye out for next week's episode of #Th... 2018-11-07         1084
# 4   Damn it, Tim. That really came full-circle. 😭 ... 2018-11-07          545
# 5   We see what you did there @whoisgreggarcia. 😉 ... 2018-11-07          472
# 6                             @Amadii 👣 #TheGuestBook 2018-11-07           31
# 7      @_Doo_Wop @JimmyTatro Shows all. #TheGuestBook 2018-11-07          112
# 8                  @Amadii Until now... #TheGuestBook 2018-11-07           63
# 9   New shoes can make a girl do crazy things. #Th... 2018-11-07          485
# 10  No underwear was soiled in the making of #TheG... 2018-11-07          430
# 11  When your twisted at 2am and someone suggests ... 2018-11-07          454
# 12           @_Doo_Wop Sounds possible. #TheGuestBook 2018-11-07           46
# 13  @JoshMarino420 Don't underestimate good Uncle ... 2018-11-07           40
# 14      @Amadii Cheers! Join the party. #TheGuestBook 2018-11-07           38
# 15  Bill's fixin' to get in on this hootenanny. #T... 2018-11-07          431
# 16  Tim's a bag half-full type of guy. Be like Tim... 2018-11-07          439
# 17  Share your favorite 🍁 recipe. #TheGuestBook ht... 2018-11-07          660
# 18  For all you singles out there wondering what m... 2018-11-07          529
# 19  This is how we say goodbye in the mountains. #... 2018-11-07          450
# 20  Keep your eyes glued to the TV. A new episode ... 2018-11-07          558
# 21  Nikki's all smiles now, but just you wait till... 2018-11-07          683
# 22  @TBSNetwork @CarlyJibson @JimmyTatro How does ... 2018-11-07          163
# 23  When celebrating new shoes turns into one wild... 2018-11-07          593
# 24  Catch him on a new episode of  #TheGuestBook t... 2018-11-06          434
# 25  @michaelcassidy sneaking up on you unexpectedl... 2018-11-06          283
# 26  @michaelcassidy sneaking up on you unexpectedl... 2018-11-06          222
# 27  Who doesn’t love a romantic, drug-induced how ... 2018-11-06         2464
# 28  Eddie Steeples is up to deliver these toes to ... 2018-11-05          593
# 29  Hit RT if @MichaelCassidy’s the reason you’ll ... 2018-11-05          746
# 30  If you love experimenting with edibles, then y... 2018-11-04         7462
# 31  What’s better than drugs? More drugs. Don't mi... 2018-11-03         1083
# 32  Eddie Steeples is up to deliver these toes to ... 2018-11-02          829
# 33  No parties... this time. 👍 #TheGuestBook is ba... 2018-11-02         1584
#
#    promoted impressions  engagements  engagement rate  retweets  replies  \
# 0                     -           31         0.057196         2        1
# 1                     -           17         0.036403         2        1
# 2                     -           18         0.033645         1        1
# 3                     -           78         0.071956         1        0
# 4                     -           20         0.036697         0        0
# 5                     -           26         0.055085         0        1
# 6                     -            1         0.032258         0        0
# 7                     -            7         0.062500         0        0
# 8                     -            2         0.031746         0        1
# 9                     -           11         0.022680         0        1
# 10                    -            8         0.018605         0        0
# 11                    -            9         0.019824         1        0
# 12                    -            1         0.021739         0        0
# 13                    -            3         0.075000         0        1
# 14                    -            1         0.026316         0        0
# 15                    -            8         0.018561         0        0
# 16                    -           10         0.022779         0        0
# 17                    -           13         0.019697         1        0
# 18                    -           15         0.028355         1        0
# 19                    -            9         0.020000         0        0
# 20                    -           21         0.037634         1        0
# 21                    -           25         0.036603         0        0
# 22                    -            7         0.042945         1        0
# 23                    -           15         0.025295         0        0
# 24                    -            6         0.013825         0        0
# 25                    -           19         0.067138         0        1
# 26                    -          186         0.837838         0        0
# 27               484181           25         0.010146         1        1
# 28                    -           23         0.038786         0        0
# 29                    -           20         0.026810         2        0
# 30                    -         2368         0.317341        13        3
# 31                    -           73         0.067405         1        1
# 32                    -           45         0.054282         1        0
# 33               732096           59         0.037247         4        1
#
#     likes    ...      media engagements post type  vis eng view rate  \
# 0      15    ...                     10      post       18  0.302583
# 1       8    ...                      1      post       11  0.205567
# 2       5    ...                     10      post        7  0.018692
# 3      12    ...                     38      post       13  0.844096
# 4       8    ...                      7      post        8  0.209174
# 5       9    ...                      9      post       10  0.199153
# 6       1    ...                      0     reply        1  0.000000
# 7       1    ...                      0     reply        1  0.000000
# 8       0    ...                      0     reply        1  0.000000
# 9       3    ...                      2      post        4  0.183505
# 10      3    ...                      1      post        3  0.155814
# 11      5    ...                      3      post        6  0.167401
# 12      1    ...                      0     reply        1  0.000000
# 13      1    ...                      0     reply        2  0.000000
# 14      1    ...                      0     reply        1  0.000000
# 15      4    ...                      4      post        4  0.150812
# 16      4    ...                      3      post        4  0.129841
# 17      9    ...                      3      post       10  0.142424
# 18      7    ...                      3      post        8  0.151229
# 19      4    ...                      2      post        4  0.142222
# 20      9    ...                      7      post       10  0.175627
# 21      5    ...                     17      post        5  0.024890
# 22      1    ...                      0     reply        2  0.000000
# 23      7    ...                      8      post        7  0.229342
# 24      1    ...                      0      post        1  0.000000
# 25      2    ...                     14     reply        3  0.049470
# 26      1    ...                    165     reply        1  0.743243
# 27      8    ...                     12      post       10  0.128247
# 28      8    ...                     13      post        8  0.224283
# 29      5    ...                     10      post        7  0.189008
# 30     64    ...                   2080      post       80  2.913160
# 31     13    ...                     50      post       15  0.259464
# 32     15    ...                     22      post       16  0.212304
# 33      4    ...                     36      post        9  0.161616
#
#     completion rate  episode  in-show votes       phase  messaging
# 0          0.018450      204      not   NaN  continuity  Evergreen
# 1          0.002141      204      not   NaN  continuity  Evergreen
# 2          0.018692      204      not   NaN  continuity  Evergreen
# 3          0.035055      204  in-show   NaN  continuity  Evergreen
# 4          0.012844      204  in-show   NaN  continuity  Evergreen
# 5          0.019068      204  in-show   NaN  continuity  Evergreen
# 6          0.000000      204  in-show   NaN  continuity  Evergreen
# 7          0.000000      204  in-show   NaN  continuity  Evergreen
# 8          0.000000      204  in-show   NaN  continuity  Evergreen
# 9          0.004124      204  in-show   NaN  continuity  Evergreen
# 10         0.002326      204  in-show   NaN  continuity  Evergreen
# 11         0.006608      204  in-show   NaN  continuity  Evergreen
# 12         0.000000      204  in-show   NaN  continuity  Evergreen
# 13         0.000000      204  in-show   NaN  continuity  Evergreen
# 14         0.000000      204  in-show   NaN  continuity  Evergreen
# 15         0.009281      204  in-show   NaN  continuity  Evergreen
# 16         0.006834      204  in-show   NaN  continuity  Evergreen
# 17         0.004545      204  in-show   NaN  continuity  Evergreen
# 18         0.005671      204  in-show   NaN  continuity  Evergreen
# 19         0.004444      204  in-show   NaN  continuity  Evergreen
# 20         0.012545      204  in-show   NaN  continuity  Evergreen
# 21         0.024890      204  in-show   NaN  continuity    Tonight
# 22         0.000000      204      not   NaN  continuity  Evergreen
# 23         0.013491      204      not   NaN  continuity  Evergreen
# 24         0.000000      204      not   NaN  continuity    Tonight
# 25         0.049470      204      not   NaN  continuity  Evergreen
# 26         0.743243      204      not   NaN  continuity  Evergreen
# 27         0.004870      204      not   NaN  continuity    Tonight
# 28         0.021922      204      not   NaN  continuity  Evergreen
# 29         0.013405      204      not   NaN  continuity  Evergreen
# 30         0.278746      204      not   NaN  continuity  Evergreen
# 31         0.046168      204      not   NaN  continuity    Tuesday
# 32         0.026538      204      not   NaN  continuity  Evergreen
# 33         0.022727      204      not   NaN  continuity    Tuesday
#
# [34 rows x 22 columns]

# %%
#standardize column names i.e. make all lowercase
twitter.columns = map(str.lower, twitter.columns)
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 22 columns):
# tweet permalink         34 non-null object
# tweet text              34 non-null object
# time                    34 non-null datetime64[ns]
# impressions             34 non-null int64
# promoted impressions    34 non-null object
# engagements             34 non-null int64
# engagement rate         34 non-null float64
# retweets                34 non-null int64
# replies                 34 non-null int64
# likes                   34 non-null int64
# media views             34 non-null int64
# promoted media views    34 non-null object
# media engagements       34 non-null int64
# post type               34 non-null object
# vis eng                 34 non-null int64
# view rate               34 non-null float64
# completion rate         34 non-null float64
# episode                 34 non-null object
# in-show                 34 non-null object
# votes                   0 non-null float64
# phase                   34 non-null object
# messaging               34 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(8), object(9)
# memory usage: 5.9+ KB

# %%
#reorder columns
twitter = twitter[['post type', 'tweet permalink', 'tweet text', 'episode', 'time', 'in-show', 'impressions','promoted impressions',
                   'engagements', 'engagement rate', 'retweets', 'replies', 'likes', 'votes', 'vis eng',
                   'media views', 'promoted media views', 'media engagements', 'view rate', 'completion rate', 'phase','messaging']]
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 22 columns):
# post type               34 non-null object
# tweet permalink         34 non-null object
# tweet text              34 non-null object
# episode                 34 non-null object
# time                    34 non-null datetime64[ns]
# in-show                 34 non-null object
# impressions             34 non-null int64
# promoted impressions    34 non-null object
# engagements             34 non-null int64
# engagement rate         34 non-null float64
# retweets                34 non-null int64
# replies                 34 non-null int64
# likes                   34 non-null int64
# votes                   0 non-null float64
# vis eng                 34 non-null int64
# media views             34 non-null int64
# promoted media views    34 non-null object
# media engagements       34 non-null int64
# view rate               34 non-null float64
# completion rate         34 non-null float64
# phase                   34 non-null object
# messaging               34 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(8), object(9)
# memory usage: 5.9+ KB

# %%
# convert new dataframe to csv "twitter_weekly.csv"
twitter.to_csv('twitter_weekly.csv')

# %% [markdown]
# ### Nielsen
#
# Read in data export from Nielsen UI, wrangle and write to csv.

# %%
# read in file for current week's episode
# air time: 11/6/18 - 10pm ET
nielsen = pd.read_csv('nielsen_weekly_pull.csv')
nielsen.info()
nielsen.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 14 columns):
# Social Content Ratings    126 non-null object
# Unnamed: 1                124 non-null object
# Unnamed: 2                115 non-null object
# Unnamed: 3                115 non-null object
# Unnamed: 4                115 non-null object
# Unnamed: 5                111 non-null object
# Unnamed: 6                111 non-null object
# Unnamed: 7                109 non-null object
# Unnamed: 8                109 non-null object
# Unnamed: 9                109 non-null object
# Unnamed: 10               109 non-null object
# Unnamed: 11               109 non-null object
# Unnamed: 12               109 non-null object
# Unnamed: 13               46 non-null object
# dtypes: object(14)
# memory usage: 14.7+ KB
#                                Social Content Ratings          Unnamed: 1  \
# 0                       http://scr.nielsensocial.com/                 NaN
# 1   Copyright 2018 The Nielsen Company.  All right...                 NaN
# 2                                                 NaN                 NaN
# 3                                             Network                 TBS
# 4                                             Program      The Guest Book
# 5                                  Program Genre Type       Comedy Series
# 6                                       Season Number                   2
# 7                                             Episode        Killer Party
# 8                                      Episode Number                   4
# 9                                      EPG Program ID      SH026058900000
# 10                                     EPG Episode ID      EP026058900025
# 11                                           Air Date             11/6/18
# 12                                 Airtime Start Time        10:30 PM EST
# 13                                 Duration (Minutes)                  30
# 14                                           Live/New                 Yes
# 15                                        Report Type  Tweets (Verbatims)
# 16                                                NaN                 NaN
# 17                                                NaN      Unique Authors
# 18                                            Twitter                  51
# 19                                                NaN                 NaN
#
#           Unnamed: 2       Unnamed: 3        Unnamed: 4 Unnamed: 5  \
# 0                NaN              NaN               NaN        NaN
# 1                NaN              NaN               NaN        NaN
# 2                NaN              NaN               NaN        NaN
# 3                NaN              NaN               NaN        NaN
# 4                NaN              NaN               NaN        NaN
# 5                NaN              NaN               NaN        NaN
# 6                NaN              NaN               NaN        NaN
# 7                NaN              NaN               NaN        NaN
# 8                NaN              NaN               NaN        NaN
# 9                NaN              NaN               NaN        NaN
# 10               NaN              NaN               NaN        NaN
# 11               NaN              NaN               NaN        NaN
# 12               NaN              NaN               NaN        NaN
# 13               NaN              NaN               NaN        NaN
# 14               NaN              NaN               NaN        NaN
# 15               NaN              NaN               NaN        NaN
# 16               NaN              NaN               NaN        NaN
# 17  Original Content  Unique Engagers  Total Engagement    Uniques
# 18                63              117               207        164
# 19          Retweets               13                16        NaN
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0            NaN        NaN        NaN        NaN         NaN         NaN
# 1            NaN        NaN        NaN        NaN         NaN         NaN
# 2            NaN        NaN        NaN        NaN         NaN         NaN
# 3            NaN        NaN        NaN        NaN         NaN         NaN
# 4            NaN        NaN        NaN        NaN         NaN         NaN
# 5            NaN        NaN        NaN        NaN         NaN         NaN
# 6            NaN        NaN        NaN        NaN         NaN         NaN
# 7            NaN        NaN        NaN        NaN         NaN         NaN
# 8            NaN        NaN        NaN        NaN         NaN         NaN
# 9            NaN        NaN        NaN        NaN         NaN         NaN
# 10           NaN        NaN        NaN        NaN         NaN         NaN
# 11           NaN        NaN        NaN        NaN         NaN         NaN
# 12           NaN        NaN        NaN        NaN         NaN         NaN
# 13           NaN        NaN        NaN        NaN         NaN         NaN
# 14           NaN        NaN        NaN        NaN         NaN         NaN
# 15           NaN        NaN        NaN        NaN         NaN         NaN
# 16           NaN        NaN        NaN        NaN         NaN         NaN
# 17  Interactions        NaN        NaN        NaN         NaN         NaN
# 18           270        NaN        NaN        NaN         NaN         NaN
# 19           NaN        NaN        NaN        NaN         NaN         NaN
#
#    Unnamed: 12 Unnamed: 13
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN

# %%
# toss row indices 0-9 into a new dataframe and isolate episode name
episode_details = nielsen.iloc[:13]
episode_details['episode'] = episode_details.iat[6,1] + str('0') + episode_details.iat[8,1]
episode_details['name'] = episode_details.iat[7,1]
episode_details['air date'] = episode_details.iat[11,1]
episode_details['air time'] = episode_details.iat[12,1]
episode_details.drop(episode_details.index[1:],inplace=True)
episode_details = episode_details.loc[:, ['episode','name','air date','air time']]
episode_details
# Out:
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#   episode          name air date      air time
# 0     204  Killer Party  11/6/18  10:30 PM EST

# %%
# bring up row index 17 as header and drop row indices 0-16
nielsen.drop(nielsen.index[:17], inplace=True)
nielsen.columns = nielsen.iloc[0]
nielsen = nielsen[1:]
nielsen = nielsen.reset_index(drop = True)
nielsen.head(15)
# Out:
# 17              NaN                       Unique Authors Original Content  \
# 0           Twitter                                   51               63
# 1               NaN                                  NaN         Retweets
# 2               NaN                                  NaN          Replies
# 3               NaN                                  NaN           Quotes
# 4               NaN                                  NaN            Likes
# 5               NaN                                  NaN              NaN
# 6            Tweets                                  NaN              NaN
# 7              User                     User Profile Url          User ID
# 8      guestbooktbs     https://twitter.com/guestbooktbs      7.56173E+17
# 9      guestbooktbs     https://twitter.com/guestbooktbs      7.56173E+17
# 10      NotYourShow      https://twitter.com/NotYourShow        574113039
# 11      Michealluby      https://twitter.com/Michealluby       4731196936
# 12   chrisnathaniel   https://twitter.com/chrisnathaniel         14465971
# 13  S00NERSunflower  https://twitter.com/S00NERSunflower       8.0382E+17
# 14   michaelcassidy   https://twitter.com/michaelcassidy         19367692
#
# 17 Unique Engagers   Total Engagement     Uniques          Interactions  \
# 0              117                207         164                   270
# 1               13                 16         NaN                   NaN
# 2               18                 24         NaN                   NaN
# 3                5                  5         NaN                   NaN
# 4               98                162         NaN                   NaN
# 5              NaN                NaN         NaN                   NaN
# 6              NaN                NaN         NaN                   NaN
# 7        Followers  Time Sent (Local)  Local Date       Time Sent (GMT)
# 8             5233    08:41:52 PM EST     11/6/18  2018-11-07T01:41:52Z
# 9             5233    08:43:02 PM EST     11/6/18  2018-11-07T01:43:02Z
# 10             135    09:11:47 PM EST     11/6/18  2018-11-07T02:11:47Z
# 11             285    09:17:09 PM EST     11/6/18  2018-11-07T02:17:09Z
# 12            1357    10:31:42 PM EST     11/6/18  2018-11-07T03:31:42Z
# 13               3    11:44:06 PM EST     11/6/18  2018-11-07T04:44:06Z
# 14            8279    11:46:20 PM EST     11/6/18  2018-11-07T04:46:20Z
#
# 17          NaN                                                NaN  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7      Tweet ID                                              Tweet
# 8   1.05998E+18  @TBSNetwork @CarlyJibson @JimmyTatro How does ...
# 9   1.05998E+18  RT @TBSNetwork: "I'm a lady and ladies swallow...
# 10  1.05999E+18  RT @TBSNetwork: "I'm a lady and ladies swallow...
# 11  1.05999E+18  RT @guestbooktbs: @TBSNetwork @CarlyJibson @Ji...
# 12  1.06001E+18  So so funny!! And make sure you’re watching @g...
# 13  1.06003E+18  @michaelcassidy It was great, my favorite epis...
# 14  1.06003E+18                        @S00NERSunflower Thank you!
#
# 17                                               NaN               NaN  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5                                                NaN               NaN
# 6                                                NaN               NaN
# 7                                          Tweet URL  Interaction Type
# 8   https://twitter.com/statuses/1059984247736287232        engagement
# 9   https://twitter.com/statuses/1059984539827679232        engagement
# 10  https://twitter.com/statuses/1059991774503026689        engagement
# 11  https://twitter.com/statuses/1059993127539429376        engagement
# 12  https://twitter.com/statuses/1060011884642893824        engagement
# 13  https://twitter.com/statuses/1060030104804491264        engagement
# 14  https://twitter.com/statuses/1060030669110206465        engagement
#
# 17         NaN          NaN                                               NaN
# 0          NaN          NaN                                               NaN
# 1          NaN          NaN                                               NaN
# 2          NaN          NaN                                               NaN
# 3          NaN          NaN                                               NaN
# 4          NaN          NaN                                               NaN
# 5          NaN          NaN                                               NaN
# 6          NaN          NaN                                               NaN
# 7   Tweet Type      Root ID                                          Root URL
# 8        reply  1.05988E+18  https://twitter.com/statuses/1059875563748257792
# 9      retweet  1.05988E+18  https://twitter.com/statuses/1059875563748257792
# 10     retweet  1.05988E+18  https://twitter.com/statuses/1059875563748257792
# 11     retweet  1.05988E+18  https://twitter.com/statuses/1059875563748257792
# 12       quote  1.05988E+18  https://twitter.com/statuses/1059875563748257792
# 13       reply  1.05988E+18  https://twitter.com/statuses/1059883033669459968
# 14       reply  1.05988E+18  https://twitter.com/statuses/1059883033669459968

# %%
# calculate value for total mentions and add as column
mentions = nielsen.iloc[8:]
nielsen['total mentions'] = mentions['Unique Authors'].count()

nielsen.head()
# Out:
# 17      NaN Unique Authors Original Content Unique Engagers Total Engagement  \
# 0   Twitter             51               63             117              207
# 1       NaN            NaN         Retweets              13               16
# 2       NaN            NaN          Replies              18               24
# 3       NaN            NaN           Quotes               5                5
# 4       NaN            NaN            Likes              98              162
#
# 17 Uniques Interactions  NaN  NaN  NaN  NaN  NaN  NaN  NaN  total mentions
# 0      164          270  NaN  NaN  NaN  NaN  NaN  NaN  NaN             108
# 1      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN             108
# 2      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN             108
# 3      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN             108
# 4      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN             108

# %%
# keep only relevant columns and drop all rows except first
nielsen = nielsen[['Unique Authors','Original Content','Unique Engagers','Interactions','total mentions']]
nielsen.drop(nielsen.index[1:], inplace=True)
nielsen.head()
# Out:
# 17 Unique Authors Original Content Unique Engagers Interactions  \
# 0              51               63             117          270
#
# 17  total mentions
# 0              108

# %%
# rename and reorder columns
nielsen.columns = ['unique users','total social convos','unique authors/engagers','interactions','total mentions']
nielsen['episode'], nielsen['name'], nielsen['air date'], nielsen['air time'] = episode_details['episode'], episode_details['name'], episode_details['air date'], episode_details['air time']
nielsen = nielsen[['episode','name','air date','air time','unique users','total social convos','unique authors/engagers','interactions','total mentions']]
nielsen.head()
# Out:
#   episode          name air date      air time unique users  \
# 0     204  Killer Party  11/6/18  10:30 PM EST           51
#
#   total social convos unique authors/engagers interactions  total mentions
# 0                  63                     117          270             108

# %%
nielsen.to_csv('nielsen_weekly.csv')

# %% [markdown]
# ### Facebook
#
# Read in data export from Facebook platform, wrangle, and write to csv.

# %%
fb = pd.read_csv('fb_weekly_pull.csv')
print(fb.info())
fb.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 54 columns):
# Post ID                                                                        11 non-null object
# Permalink                                                                      11 non-null object
# Post Message                                                                   11 non-null object
# Type                                                                           11 non-null object
# Countries                                                                      0 non-null float64
# Languages                                                                      0 non-null float64
# Posted                                                                         11 non-null object
# Audience Targeting                                                             11 non-null object
# Lifetime Post Total Reach                                                      12 non-null object
# Lifetime Post organic reach                                                    12 non-null object
# Lifetime Post Paid Reach                                                       12 non-null object
# Lifetime Post Total Impressions                                                12 non-null object
# Lifetime Post Organic Impressions                                              12 non-null object
# Lifetime Post Paid Impressions                                                 12 non-null object
# Lifetime Engaged Users                                                         12 non-null object
# Lifetime Matched Audience Targeting Consumers on Post                          12 non-null object
# Lifetime Matched Audience Targeting Consumptions on Post                       12 non-null object
# Lifetime Negative Feedback from Users                                          12 non-null object
# Lifetime Negative Feedback                                                     12 non-null object
# Lifetime Post Impressions by people who have liked your Page                   12 non-null object
# Lifetime Post reach by people who like your Page                               12 non-null object
# Lifetime Post Paid Impressions by people who have liked your Page              12 non-null object
# Lifetime Paid reach of a post by people who like your Page                     12 non-null object
# Lifetime People who have liked your Page and engaged with your post            12 non-null object
# Lifetime Organic views to 95%                                                  12 non-null object
# Lifetime Organic views to 95%.1                                                12 non-null object
# Lifetime Paid views to 95%                                                     12 non-null object
# Lifetime Paid views to 95%.1                                                   12 non-null object
# Lifetime Organic Video Views                                                   12 non-null object
# Lifetime Organic Video Views.1                                                 12 non-null object
# Lifetime Paid Video Views                                                      12 non-null object
# Lifetime Paid Video Views.1                                                    12 non-null object
# Lifetime Average time video viewed                                             12 non-null object
# Lifetime Video length                                                          12 non-null object
# Lifetime Talking About This (Post) by action type - like                       12 non-null object
# Lifetime Talking About This (Post) by action type - comment                    9 non-null float64
# Lifetime Talking About This (Post) by action type - share                      6 non-null float64
# Lifetime Post Stories by action type - like                                    12 non-null object
# Lifetime Post Stories by action type - comment                                 9 non-null float64
# Lifetime Post Stories by action type - share                                   6 non-null float64
# Lifetime Post Audience Targeting Unique Consumptions by Type - video play      11 non-null object
# Lifetime Post Audience Targeting Unique Consumptions by Type - other clicks    11 non-null float64
# Lifetime Post Audience Targeting Unique Consumptions by Type - link clicks     2 non-null float64
# Lifetime Post Audience Targeting Unique Consumptions by Type - photo view      1 non-null float64
# Lifetime Matched Audience Targeting Consumptions by Type - video play          11 non-null object
# Lifetime Matched Audience Targeting Consumptions by Type - other clicks        11 non-null float64
# Lifetime Matched Audience Targeting Consumptions by Type - link clicks         2 non-null float64
# Lifetime Matched Audience Targeting Consumptions by Type - photo view          1 non-null float64
# Lifetime Negative Feedback from Users by Type - hide_all_clicks                8 non-null object
# Lifetime Negative Feedback from Users by Type - hide_clicks                    4 non-null float64
# Lifetime Negative Feedback from Users by Type - report_spam_clicks             2 non-null float64
# Lifetime Negative Feedback by Type - hide_all_clicks                           8 non-null object
# Lifetime Negative Feedback by Type - hide_clicks                               4 non-null float64
# Lifetime Negative Feedback by Type - report_spam_clicks                        2 non-null float64
# dtypes: float64(16), object(38)
# memory usage: 5.1+ KB
# None
#                              Post ID  \
# 0                                NaN
# 1  1067035793417549_1996395563814896
# 2  1067035793417549_1996179110503208
# 3  1067035793417549_2214892745457260
# 4  1067035793417549_1993811160740003
#
#                                            Permalink  \
# 0                                                NaN
# 1  https://www.facebook.com/guestbooktbs/posts/19...
# 2  https://www.facebook.com/guestbooktbs/posts/19...
# 3  https://www.facebook.com/guestbooktbs/videos/2...
# 4  https://www.facebook.com/guestbooktbs/posts/19...
#
#                                         Post Message   Type  Countries  \
# 0                                                NaN    NaN        NaN
# 1  Fact: diarrhea can't partake in no-shave Novem...  Video        NaN
# 2  Tag someone that would be perfect for the role...  Video        NaN
# 3  Every vacation has a weird story, or two. So w...  Video        NaN
# 4  When celebrating new shoes turns into one wild...  Video        NaN
#
#    Languages         Posted Audience Targeting  \
# 0        NaN            NaN                NaN
# 1        NaN  11/8/18 15:42
# 2        NaN  11/8/18 11:25
# 3        NaN  11/7/18 15:00
# 4        NaN  11/6/18 16:14
#
#                            Lifetime Post Total Reach  \
# 0  Lifetime: The number of people who had your Pa...
# 1                                               1732
# 2                                                638
# 3                                               3527
# 4                                               1652
#
#                          Lifetime Post organic reach  \
# 0  Lifetime: The number of people who had your Pa...
# 1                                               1732
# 2                                                638
# 3                                               3527
# 4                                               1652
#
#                             ...                            \
# 0                           ...
# 1                           ...
# 2                           ...
# 3                           ...
# 4                           ...
#
#   Lifetime Matched Audience Targeting Consumptions by Type - video play  \
# 0  Lifetime: The number of clicks anywhere in the...
# 1                                                 12
# 2                                                  8
# 3                                                 33
# 4                                                 29
#
#   Lifetime Matched Audience Targeting Consumptions by Type - other clicks  \
# 0                                                NaN
# 1                                               46.0
# 2                                               18.0
# 3                                              127.0
# 4                                               39.0
#
#   Lifetime Matched Audience Targeting Consumptions by Type - link clicks  \
# 0                                                NaN
# 1                                                NaN
# 2                                                1.0
# 3                                                2.0
# 4                                                NaN
#
#   Lifetime Matched Audience Targeting Consumptions by Type - photo view  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Lifetime Negative Feedback from Users by Type - hide_all_clicks  \
# 0  Lifetime: The number of times people have give...
# 1                                                  2
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#   Lifetime Negative Feedback from Users by Type - hide_clicks  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Lifetime Negative Feedback from Users by Type - report_spam_clicks  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Lifetime Negative Feedback by Type - hide_all_clicks  \
# 0  Lifetime: The number of people who have given ...
# 1                                                  2
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#   Lifetime Negative Feedback by Type - hide_clicks  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Lifetime Negative Feedback by Type - report_spam_clicks
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 54 columns]

# %%
#drop unwanted rows and columns
# 'Lifetime Post Stories by action type - like', 'Lifetime Post Stories by action type - comment', 'Lifetime Post Stories by action type - share'
fb.drop(fb.index[0], inplace=True)
fb = fb.filter(['Permalink','Posted','Post Message','Type','Lifetime Post organic reach','Lifetime Post Organic Impressions', 'Lifetime Post Paid Impressions','Lifetime Engaged Users','Lifetime Organic Video Views.1','Lifetime Paid Video Views','Lifetime Organic views to 95%.1','Lifetime Paid views to 95%.1','Lifetime Talking About This (Post) by action type - like','Lifetime Talking About This (Post) by action type - comment','Lifetime Talking About This (Post) by action type - share','Lifetime Post Stories by action type - like', 'Lifetime Post Stories by action type - comment', 'Lifetime Post Stories by action type - share'])
fb = fb.reset_index(drop=True)
print(fb.info())
fb.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 18 columns):
# Permalink                                                      11 non-null object
# Posted                                                         11 non-null object
# Post Message                                                   11 non-null object
# Type                                                           11 non-null object
# Lifetime Post organic reach                                    11 non-null object
# Lifetime Post Organic Impressions                              11 non-null object
# Lifetime Post Paid Impressions                                 11 non-null object
# Lifetime Engaged Users                                         11 non-null object
# Lifetime Organic Video Views.1                                 11 non-null object
# Lifetime Paid Video Views                                      11 non-null object
# Lifetime Organic views to 95%.1                                11 non-null object
# Lifetime Paid views to 95%.1                                   11 non-null object
# Lifetime Talking About This (Post) by action type - like       11 non-null object
# Lifetime Talking About This (Post) by action type - comment    9 non-null float64
# Lifetime Talking About This (Post) by action type - share      6 non-null float64
# Lifetime Post Stories by action type - like                    11 non-null object
# Lifetime Post Stories by action type - comment                 9 non-null float64
# Lifetime Post Stories by action type - share                   6 non-null float64
# dtypes: float64(4), object(14)
# memory usage: 1.6+ KB
# None
#                                            Permalink         Posted  \
# 0  https://www.facebook.com/guestbooktbs/posts/19...  11/8/18 15:42
# 1  https://www.facebook.com/guestbooktbs/posts/19...  11/8/18 11:25
# 2  https://www.facebook.com/guestbooktbs/videos/2...  11/7/18 15:00
# 3  https://www.facebook.com/guestbooktbs/posts/19...  11/6/18 16:14
# 4  https://www.facebook.com/guestbooktbs/posts/19...  11/6/18 11:03
#
#                                         Post Message   Type  \
# 0  Fact: diarrhea can't partake in no-shave Novem...  Video
# 1  Tag someone that would be perfect for the role...  Video
# 2  Every vacation has a weird story, or two. So w...  Video
# 3  When celebrating new shoes turns into one wild...  Video
# 4  Michael Cassidy sneaking up on you unexpectedl...  Photo
#
#   Lifetime Post organic reach Lifetime Post Organic Impressions  \
# 0                        1732                              2291
# 1                         638                               834
# 2                        3527                              4657
# 3                        1652                              2222
# 4                        3630                              4539
#
#   Lifetime Post Paid Impressions Lifetime Engaged Users  \
# 0                              0                     59
# 1                              0                     32
# 2                              0                    130
# 3                              0                     56
# 4                              0                    113
#
#   Lifetime Organic Video Views.1 Lifetime Paid Video Views  \
# 0                            695                         0
# 1                            247                         0
# 2                            831                         0
# 3                            871                         0
# 4                              0                         0
#
#   Lifetime Organic views to 95%.1 Lifetime Paid views to 95%.1  \
# 0                             343                            0
# 1                              83                            0
# 2                               2                            0
# 3                             423                            0
# 4                               0                            0
#
#   Lifetime Talking About This (Post) by action type - like  \
# 0                                                 23
# 1                                                 18
# 2                                                 29
# 3                                                 11
# 4                                                 37
#
#    Lifetime Talking About This (Post) by action type - comment  \
# 0                                                1.0
# 1                                                NaN
# 2                                               29.0
# 3                                                6.0
# 4                                                9.0
#
#    Lifetime Talking About This (Post) by action type - share  \
# 0                                                NaN
# 1                                                NaN
# 2                                                1.0
# 3                                                NaN
# 4                                                2.0
#
#   Lifetime Post Stories by action type - like  \
# 0                                          26
# 1                                          18
# 2                                          32
# 3                                          12
# 4                                          38
#
#    Lifetime Post Stories by action type - comment  \
# 0                                             1.0
# 1                                             NaN
# 2                                           100.0
# 3                                             8.0
# 4                                            10.0
#
#    Lifetime Post Stories by action type - share
# 0                                           NaN
# 1                                           NaN
# 2                                           1.0
# 3                                           NaN
# 4                                           2.0

# %%
#rename columns
fb.columns = ['link','date posted','message','media type','reach','organic impressions','paid impressions','engagement','organic video views','paid video views','organic video completes','paid video completes','unq likes','unq comments','unq shares','agg likes','agg comments', 'agg shares']
fb.head()
# Out:
#                                                 link    date posted  \
# 0  https://www.facebook.com/guestbooktbs/posts/19...  11/8/18 15:42
# 1  https://www.facebook.com/guestbooktbs/posts/19...  11/8/18 11:25
# 2  https://www.facebook.com/guestbooktbs/videos/2...  11/7/18 15:00
# 3  https://www.facebook.com/guestbooktbs/posts/19...  11/6/18 16:14
# 4  https://www.facebook.com/guestbooktbs/posts/19...  11/6/18 11:03
#
#                                              message media type reach  \
# 0  Fact: diarrhea can't partake in no-shave Novem...      Video  1732
# 1  Tag someone that would be perfect for the role...      Video   638
# 2  Every vacation has a weird story, or two. So w...      Video  3527
# 3  When celebrating new shoes turns into one wild...      Video  1652
# 4  Michael Cassidy sneaking up on you unexpectedl...      Photo  3630
#
#   organic impressions paid impressions engagement organic video views  \
# 0                2291                0         59                 695
# 1                 834                0         32                 247
# 2                4657                0        130                 831
# 3                2222                0         56                 871
# 4                4539                0        113                   0
#
#   paid video views organic video completes paid video completes unq likes  \
# 0                0                     343                    0        23
# 1                0                      83                    0        18
# 2                0                       2                    0        29
# 3                0                     423                    0        11
# 4                0                       0                    0        37
#
#    unq comments  unq shares agg likes  agg comments  agg shares
# 0           1.0         NaN        26           1.0         NaN
# 1           NaN         NaN        18           NaN         NaN
# 2          29.0         1.0        32         100.0         1.0
# 3           6.0         NaN        12           8.0         NaN
# 4           9.0         2.0        38          10.0         2.0

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 18 columns):
# link                       11 non-null object
# date posted                11 non-null object
# message                    11 non-null object
# media type                 11 non-null object
# reach                      11 non-null object
# organic impressions        11 non-null object
# paid impressions           11 non-null object
# engagement                 11 non-null object
# organic video views        11 non-null object
# paid video views           11 non-null object
# organic video completes    11 non-null object
# paid video completes       11 non-null object
# unq likes                  11 non-null object
# unq comments               9 non-null float64
# unq shares                 6 non-null float64
# agg likes                  11 non-null object
# agg comments               9 non-null float64
# agg shares                 6 non-null float64
# dtypes: float64(4), object(14)
# memory usage: 1.6+ KB

# %%
fb = fb.fillna(0)

cols = ['unq likes','unq comments','unq shares','agg likes','agg comments', 'agg shares','reach','organic impressions','paid impressions','engagement','organic video views','paid video views','organic video completes','paid video completes']

for col in cols:
    fb[col] = fb[col].astype(int)
    
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 18 columns):
# link                       11 non-null object
# date posted                11 non-null object
# message                    11 non-null object
# media type                 11 non-null object
# reach                      11 non-null int64
# organic impressions        11 non-null int64
# paid impressions           11 non-null int64
# engagement                 11 non-null int64
# organic video views        11 non-null int64
# paid video views           11 non-null int64
# organic video completes    11 non-null int64
# paid video completes       11 non-null int64
# unq likes                  11 non-null int64
# unq comments               11 non-null int64
# unq shares                 11 non-null int64
# agg likes                  11 non-null int64
# agg comments               11 non-null int64
# agg shares                 11 non-null int64
# dtypes: int64(14), object(4)
# memory usage: 1.6+ KB

# %%
fb['date posted'] = pd.to_datetime(fb['date posted'])
fb['date posted'] = fb['date posted'].dt.normalize()
print(fb['date posted'].dtype)
fb.head()
# Out:
# datetime64[ns]
#                                                 link date posted  \
# 0  https://www.facebook.com/guestbooktbs/posts/19...  2018-11-08
# 1  https://www.facebook.com/guestbooktbs/posts/19...  2018-11-08
# 2  https://www.facebook.com/guestbooktbs/videos/2...  2018-11-07
# 3  https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
# 4  https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
#
#                                              message media type  reach  \
# 0  Fact: diarrhea can't partake in no-shave Novem...      Video   1732
# 1  Tag someone that would be perfect for the role...      Video    638
# 2  Every vacation has a weird story, or two. So w...      Video   3527
# 3  When celebrating new shoes turns into one wild...      Video   1652
# 4  Michael Cassidy sneaking up on you unexpectedl...      Photo   3630
#
#    organic impressions  paid impressions  engagement  organic video views  \
# 0                 2291                 0          59                  695
# 1                  834                 0          32                  247
# 2                 4657                 0         130                  831
# 3                 2222                 0          56                  871
# 4                 4539                 0         113                    0
#
#    paid video views  organic video completes  paid video completes  unq likes  \
# 0                 0                      343                     0         23
# 1                 0                       83                     0         18
# 2                 0                        2                     0         29
# 3                 0                      423                     0         11
# 4                 0                        0                     0         37
#
#    unq comments  unq shares  agg likes  agg comments  agg shares
# 0             1           0         26             1           0
# 1             0           0         18             0           0
# 2            29           1         32           100           1
# 3             6           0         12             8           0
# 4             9           2         38            10           2

# %%
## Create and add needed columns
fb['unq vis eng'] = fb['unq shares'] + fb['unq likes'] + fb['unq comments']
fb['agg vis eng'] = fb['agg shares'] + fb['agg likes'] + fb['agg comments']
fb['PAID'] = fb['paid impressions'].map(lambda x: "PAID" if x > 0 else "ORG")
fb['episode'] = '204'
fb['ER'] = fb['engagement']/fb['reach']
fb['VR'] = fb['organic video views']/fb['organic impressions']
fb['CR'] = fb['organic video completes']/fb['organic impressions']

#Phase = pre-premiere/premiere week/premiere day/continuity/finale/off season
fb['phase'] = 'continuity'
#fb['date posted'].map(lambda x: "premiere day" if x == pd.to_datetime(['2018-10-23 00:00:00']) else "premiere week")

fb
# Out:
#                                                  link date posted  \
# 0   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-08
# 1   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-08
# 2   https://www.facebook.com/guestbooktbs/videos/2...  2018-11-07
# 3   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
# 4   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
# 5   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
# 6   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-05
# 7   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-05
# 8   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-04
# 9   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-02
# 10  https://www.facebook.com/guestbooktbs/posts/19...  2018-11-02
#
#                                               message media type  reach  \
# 0   Fact: diarrhea can't partake in no-shave Novem...      Video   1732
# 1   Tag someone that would be perfect for the role...      Video    638
# 2   Every vacation has a weird story, or two. So w...      Video   3527
# 3   When celebrating new shoes turns into one wild...      Video   1652
# 4   Michael Cassidy sneaking up on you unexpectedl...      Photo   3630
# 5   Drugs are nice. And we've got a lot. The Guest...      Video   1452
# 6   Eddie Steeples is up to deliver these toes to ...      Video   1061
# 7   That’s Tim 👇 He’s a big fan of birthday cookies 🍁      Video   1562
# 8   What else would you bring to the party? Joey D...      Video   1648
# 9   It isn't a party until you do body shots with ...      Video   2202
# 10  No parties... this time. 👍 The Guest Book is b...      Video   5746
#
#     organic impressions  paid impressions  engagement  organic video views  \
# 0                  2291                 0          59                  695
# 1                   834                 0          32                  247
# 2                  4657                 0         130                  831
# 3                  2222                 0          56                  871
# 4                  4539                 0         113                    0
# 5                  1946           1403113        6259                  411
# 6                  1321                 0          57                  631
# 7                  1964                 0          37                  522
# 8                  2281                 0          69                  663
# 9                  2942                 0         103                  962
# 10                 7211            987417       20928                 1733
#
#     paid video views     ...      agg comments  agg shares  unq vis eng  \
# 0                  0     ...                 1           0           24
# 1                  0     ...                 0           0           18
# 2                  0     ...               100           1           59
# 3                  0     ...                 8           0           17
# 4                  0     ...                10           2           48
# 5             523150     ...                 5          10          165
# 6                  0     ...                 1           0           19
# 7                  0     ...                 0           0           11
# 8                  0     ...                 2           3           33
# 9                  0     ...                 4           3           30
# 10            377238     ...                35          92          938
#
#     agg vis eng  PAID  episode        ER        VR        CR       phase
# 0            27   ORG      204  0.034065  0.303361  0.149716  continuity
# 1            18   ORG      204  0.050157  0.296163  0.099520  continuity
# 2           133   ORG      204  0.036859  0.178441  0.000429  continuity
# 3            20   ORG      204  0.033898  0.391989  0.190369  continuity
# 4            50   ORG      204  0.031129  0.000000  0.000000  continuity
# 5           165  PAID      204  4.310606  0.211202  0.084275  continuity
# 6            19   ORG      204  0.053723  0.477668  0.033308  continuity
# 7            11   ORG      204  0.023688  0.265784  0.089613  continuity
# 8            34   ORG      204  0.041869  0.290662  0.185445  continuity
# 9            32   ORG      204  0.046776  0.326988  0.052005  continuity
# 10          964  PAID      204  3.642186  0.240327  0.036472  continuity
#
# [11 rows x 26 columns]

# %%
#create "messaging" column: 
#if message contains "Premiere", "Tues", "Tomorrow", "Tonight", "On Demand", "TBS App", "Evergreen"
#label as: Premieres,Tuesday,Tomorrow,Tonight,On Demand,TBS App, Evergreen
#fb['messaging'] = fb['message'].map(lambda x: "Premieres" if x == '\s*([^!.?]*?premiere[^!.?]*?)' else "Tuesday" if x == '\s*([^!.?]*?Tues[^!.?]*?)' else "Tomorrow" if x == '\s*([^!.?]*?Tomorrow[^!.?]*?)' else "Tonight" if x == '\s*([^!.?]*?Tonight[^!.?]*?)' else "On Demand" if x == '\s*([^!.?]*?On\sDemand[^!.?]*?)' else "TBS App" if x == '\s*([^!.?]*?TBS\sApp[^!.?]*?)' else "Evergreen")
fb['messaging'] = fb['message'].map(lambda x: "Premiere" if 'premiere' in x else "Tuesday" if 'Tues' in x 
                                    else "Tuesday" if 'Tuesday' in x else "Tomorrow" if 'tomorrow' in x 
                                    else "Tonight" if 'tonight' in x else "Tonight" if 'TONIGHT' in x 
                                    else "On Demand" if 'on demand' in x else "TBS App" if 'TBS App' in x
                                    else "Tomorrow" if 'Tomorrow' in x else "Tonight" if 'Tonight' in x
                                    else "Tonight" if 'TONIGHT' in x else "Evergreen")
fb
# Out:
#                                                  link date posted  \
# 0   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-08
# 1   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-08
# 2   https://www.facebook.com/guestbooktbs/videos/2...  2018-11-07
# 3   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
# 4   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
# 5   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-06
# 6   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-05
# 7   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-05
# 8   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-04
# 9   https://www.facebook.com/guestbooktbs/posts/19...  2018-11-02
# 10  https://www.facebook.com/guestbooktbs/posts/19...  2018-11-02
#
#                                               message media type  reach  \
# 0   Fact: diarrhea can't partake in no-shave Novem...      Video   1732
# 1   Tag someone that would be perfect for the role...      Video    638
# 2   Every vacation has a weird story, or two. So w...      Video   3527
# 3   When celebrating new shoes turns into one wild...      Video   1652
# 4   Michael Cassidy sneaking up on you unexpectedl...      Photo   3630
# 5   Drugs are nice. And we've got a lot. The Guest...      Video   1452
# 6   Eddie Steeples is up to deliver these toes to ...      Video   1061
# 7   That’s Tim 👇 He’s a big fan of birthday cookies 🍁      Video   1562
# 8   What else would you bring to the party? Joey D...      Video   1648
# 9   It isn't a party until you do body shots with ...      Video   2202
# 10  No parties... this time. 👍 The Guest Book is b...      Video   5746
#
#     organic impressions  paid impressions  engagement  organic video views  \
# 0                  2291                 0          59                  695
# 1                   834                 0          32                  247
# 2                  4657                 0         130                  831
# 3                  2222                 0          56                  871
# 4                  4539                 0         113                    0
# 5                  1946           1403113        6259                  411
# 6                  1321                 0          57                  631
# 7                  1964                 0          37                  522
# 8                  2281                 0          69                  663
# 9                  2942                 0         103                  962
# 10                 7211            987417       20928                 1733
#
#     paid video views    ...      agg shares  unq vis eng  agg vis eng  PAID  \
# 0                  0    ...               0           24           27   ORG
# 1                  0    ...               0           18           18   ORG
# 2                  0    ...               1           59          133   ORG
# 3                  0    ...               0           17           20   ORG
# 4                  0    ...               2           48           50   ORG
# 5             523150    ...              10          165          165  PAID
# 6                  0    ...               0           19           19   ORG
# 7                  0    ...               0           11           11   ORG
# 8                  0    ...               3           33           34   ORG
# 9                  0    ...               3           30           32   ORG
# 10            377238    ...              92          938          964  PAID
#
#     episode        ER        VR        CR       phase  messaging
# 0       204  0.034065  0.303361  0.149716  continuity  Evergreen
# 1       204  0.050157  0.296163  0.099520  continuity    TBS App
# 2       204  0.036859  0.178441  0.000429  continuity  Evergreen
# 3       204  0.033898  0.391989  0.190369  continuity  Evergreen
# 4       204  0.031129  0.000000  0.000000  continuity  Evergreen
# 5       204  4.310606  0.211202  0.084275  continuity    Tonight
# 6       204  0.053723  0.477668  0.033308  continuity  Evergreen
# 7       204  0.023688  0.265784  0.089613  continuity  Evergreen
# 8       204  0.041869  0.290662  0.185445  continuity    Tuesday
# 9       204  0.046776  0.326988  0.052005  continuity    Tuesday
# 10      204  3.642186  0.240327  0.036472  continuity    Tuesday
#
# [11 rows x 27 columns]

# %%
fb = fb[['date posted','link','message','media type','PAID','episode','reach','organic impressions','paid impressions','engagement','ER','unq likes','unq comments','unq shares','unq vis eng','agg likes','agg comments','agg shares','agg vis eng','organic video views','paid video views','organic video completes','paid video completes','VR','CR','phase','messaging']]
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 27 columns):
# date posted                11 non-null datetime64[ns]
# link                       11 non-null object
# message                    11 non-null object
# media type                 11 non-null object
# PAID                       11 non-null object
# episode                    11 non-null object
# reach                      11 non-null int64
# organic impressions        11 non-null int64
# paid impressions           11 non-null int64
# engagement                 11 non-null int64
# ER                         11 non-null float64
# unq likes                  11 non-null int64
# unq comments               11 non-null int64
# unq shares                 11 non-null int64
# unq vis eng                11 non-null int64
# agg likes                  11 non-null int64
# agg comments               11 non-null int64
# agg shares                 11 non-null int64
# agg vis eng                11 non-null int64
# organic video views        11 non-null int64
# paid video views           11 non-null int64
# organic video completes    11 non-null int64
# paid video completes       11 non-null int64
# VR                         11 non-null float64
# CR                         11 non-null float64
# phase                      11 non-null object
# messaging                  11 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(16), object(7)
# memory usage: 2.4+ KB

# %%
fb.to_csv('fb_weekly.csv')

# %% [markdown]
# ### IG Organic
#
# Read in data export from Tracer, wrangle, and write to csv.

# %%
ig = pd.read_csv('ig_org_weekly_pull.csv')
print(ig.info())
ig.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
# Page Name              9 non-null object
# Post Created Date      8 non-null object
# Post Permalink         8 non-null object
# Post Media Type        8 non-null object
# Post Caption           8 non-null object
# Reach                  8 non-null float64
# Impressions            8 non-null float64
# Post Comments Count    8 non-null float64
# Post Like Count        8 non-null float64
# Engagement             8 non-null float64
# Video Views            8 non-null float64
# dtypes: float64(6), object(5)
# memory usage: 960.0+ bytes
# None
#         Page Name Post Created Date                            Post Permalink  \
# 0  The Guest Book           11/4/18  https://www.instagram.com/p/BpxWbo-nD85/
# 1  The Guest Book           11/5/18  https://www.instagram.com/p/Bpz6LCCHYAQ/
# 2  The Guest Book           11/5/18  https://www.instagram.com/p/BpzkKiIn4AI/
# 3  The Guest Book           11/6/18  https://www.instagram.com/p/Bp2ZojTHEVN/
# 4  The Guest Book           11/7/18  https://www.instagram.com/p/Bp2-Oiogupi/
#
#   Post Media Type                                       Post Caption   Reach  \
# 0           VIDEO  If you love experimenting with edibles, then y...  4655.0
# 1           VIDEO  @EddieSteeples is up to deliver these toes to ...  2152.0
# 2           VIDEO  If Tommy told you not to party in his beach ho...  1825.0
# 3           IMAGE  Michael Cassidy sneaking up on you unexpectedl...  2811.0
# 4           VIDEO  When celebrating new shoes turns into one wild...  2060.0
#
#    Impressions  Post Comments Count  Post Like Count  Engagement  Video Views
# 0       5046.0                  4.0            113.0       131.0       3579.0
# 1       2490.0                  6.0             88.0        99.0       1258.0
# 2       2032.0                  4.0             41.0        46.0        990.0
# 3       3165.0                  5.0            111.0       119.0          0.0
# 4       2435.0                  6.0             84.0        94.0       1384.0

# %%
#drop unwanted columns
ig.drop(columns = ['Page Name'], axis=1, inplace=True)
ig.drop(ig.index[-2:], inplace=True)
ig
# Out:
#   Post Created Date                            Post Permalink Post Media Type  \
# 0           11/4/18  https://www.instagram.com/p/BpxWbo-nD85/           VIDEO
# 1           11/5/18  https://www.instagram.com/p/Bpz6LCCHYAQ/           VIDEO
# 2           11/5/18  https://www.instagram.com/p/BpzkKiIn4AI/           VIDEO
# 3           11/6/18  https://www.instagram.com/p/Bp2ZojTHEVN/           IMAGE
# 4           11/7/18  https://www.instagram.com/p/Bp2-Oiogupi/           VIDEO
# 5           11/7/18  https://www.instagram.com/p/Bp5Wia-AAXJ/           IMAGE
# 6           11/8/18  https://www.instagram.com/p/Bp7mKMSAI30/           VIDEO
# 7           11/8/18  https://www.instagram.com/p/Bp8D81sglZN/           VIDEO
#
#                                         Post Caption   Reach  Impressions  \
# 0  If you love experimenting with edibles, then y...  4655.0       5046.0
# 1  @EddieSteeples is up to deliver these toes to ...  2152.0       2490.0
# 2  If Tommy told you not to party in his beach ho...  1825.0       2032.0
# 3  Michael Cassidy sneaking up on you unexpectedl...  2811.0       3165.0
# 4  When celebrating new shoes turns into one wild...  2060.0       2435.0
# 5  Every vacation has a weird story, or two. So w...   754.0        939.0
# 6  Ecstasy. That is all. Click the link in our bi...  1180.0       1396.0
# 7  Fact: diarrhea can't partake in no-shave Novem...  1141.0       1375.0
#
#    Post Comments Count  Post Like Count  Engagement  Video Views
# 0                  4.0            113.0       131.0       3579.0
# 1                  6.0             88.0        99.0       1258.0
# 2                  4.0             41.0        46.0        990.0
# 3                  5.0            111.0       119.0          0.0
# 4                  6.0             84.0        94.0       1384.0
# 5                  0.0             44.0        44.0          0.0
# 6                  4.0             72.0        79.0        651.0
# 7                  2.0             76.0        81.0        614.0

# %%
#rename columns
ig.columns = ['date','link','media type','caption','reach','impressions','comments','likes','engagement','video views']

#add columns
ig['episode'] = '204'
ig['vis eng'] = ig['likes'] + ig['comments']
ig['eng rate'] = ig['engagement']/ig['impressions']
ig['view rate'] = ig['video views']/ig['impressions']

ig['date'] = pd.to_datetime(ig['date'])
ig['date'] = ig['date'].dt.normalize()

#Phase = pre-premiere/premiere week/premiere day/continuity/finale/off season
ig['phase'] = 'continuity'
#ig['date'].map(lambda x: "premiere day" if x == pd.to_datetime(['2018-10-23 00:00:00']) else "premiere week")

print(ig.info())
ig.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 7
# Data columns (total 15 columns):
# date           8 non-null datetime64[ns]
# link           8 non-null object
# media type     8 non-null object
# caption        8 non-null object
# reach          8 non-null float64
# impressions    8 non-null float64
# comments       8 non-null float64
# likes          8 non-null float64
# engagement     8 non-null float64
# video views    8 non-null float64
# episode        8 non-null object
# vis eng        8 non-null float64
# eng rate       8 non-null float64
# view rate      8 non-null float64
# phase          8 non-null object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 1.0+ KB
# None
#         date                                      link media type  \
# 0 2018-11-04  https://www.instagram.com/p/BpxWbo-nD85/      VIDEO
# 1 2018-11-05  https://www.instagram.com/p/Bpz6LCCHYAQ/      VIDEO
# 2 2018-11-05  https://www.instagram.com/p/BpzkKiIn4AI/      VIDEO
# 3 2018-11-06  https://www.instagram.com/p/Bp2ZojTHEVN/      IMAGE
# 4 2018-11-07  https://www.instagram.com/p/Bp2-Oiogupi/      VIDEO
#
#                                              caption   reach  impressions  \
# 0  If you love experimenting with edibles, then y...  4655.0       5046.0
# 1  @EddieSteeples is up to deliver these toes to ...  2152.0       2490.0
# 2  If Tommy told you not to party in his beach ho...  1825.0       2032.0
# 3  Michael Cassidy sneaking up on you unexpectedl...  2811.0       3165.0
# 4  When celebrating new shoes turns into one wild...  2060.0       2435.0
#
#    comments  likes  engagement  video views episode  vis eng  eng rate  \
# 0       4.0  113.0       131.0       3579.0     204    117.0  0.025961
# 1       6.0   88.0        99.0       1258.0     204     94.0  0.039759
# 2       4.0   41.0        46.0        990.0     204     45.0  0.022638
# 3       5.0  111.0       119.0          0.0     204    116.0  0.037599
# 4       6.0   84.0        94.0       1384.0     204     90.0  0.038604
#
#    view rate       phase
# 0   0.709275  continuity
# 1   0.505221  continuity
# 2   0.487205  continuity
# 3   0.000000  continuity
# 4   0.568378  continuity

# %%
#messaging column based on caption containing certain words
ig['messaging'] = ig['caption'].map(lambda x: "Premiere" if 'premiere' in x else "Tuesday" if 'Tues' in x 
                                    else "Tuesday" if 'Tuesday' in x else "Tomorrow" if 'tomorrow' in x 
                                    else "Tomorrow" if "TOMORROW" in x else "Tonight" if 'tonight' in x 
                                    else "Tonight" if 'TONIGHT' in x else "On Demand" if 'on demand' in x 
                                    else "TBS App" if 'TBS App' in x else "Tomorrow" if 'Tomorrow' in x 
                                    else "Tonight" if 'Tonight' in x else "Evergreen")

print(ig.info())
ig.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 7
# Data columns (total 16 columns):
# date           8 non-null datetime64[ns]
# link           8 non-null object
# media type     8 non-null object
# caption        8 non-null object
# reach          8 non-null float64
# impressions    8 non-null float64
# comments       8 non-null float64
# likes          8 non-null float64
# engagement     8 non-null float64
# video views    8 non-null float64
# episode        8 non-null object
# vis eng        8 non-null float64
# eng rate       8 non-null float64
# view rate      8 non-null float64
# phase          8 non-null object
# messaging      8 non-null object
# dtypes: datetime64[ns](1), float64(9), object(6)
# memory usage: 1.1+ KB
# None
#         date                                      link media type  \
# 0 2018-11-04  https://www.instagram.com/p/BpxWbo-nD85/      VIDEO
# 1 2018-11-05  https://www.instagram.com/p/Bpz6LCCHYAQ/      VIDEO
# 2 2018-11-05  https://www.instagram.com/p/BpzkKiIn4AI/      VIDEO
# 3 2018-11-06  https://www.instagram.com/p/Bp2ZojTHEVN/      IMAGE
# 4 2018-11-07  https://www.instagram.com/p/Bp2-Oiogupi/      VIDEO
#
#                                              caption   reach  impressions  \
# 0  If you love experimenting with edibles, then y...  4655.0       5046.0
# 1  @EddieSteeples is up to deliver these toes to ...  2152.0       2490.0
# 2  If Tommy told you not to party in his beach ho...  1825.0       2032.0
# 3  Michael Cassidy sneaking up on you unexpectedl...  2811.0       3165.0
# 4  When celebrating new shoes turns into one wild...  2060.0       2435.0
#
#    comments  likes  engagement  video views episode  vis eng  eng rate  \
# 0       4.0  113.0       131.0       3579.0     204    117.0  0.025961
# 1       6.0   88.0        99.0       1258.0     204     94.0  0.039759
# 2       4.0   41.0        46.0        990.0     204     45.0  0.022638
# 3       5.0  111.0       119.0          0.0     204    116.0  0.037599
# 4       6.0   84.0        94.0       1384.0     204     90.0  0.038604
#
#    view rate       phase  messaging
# 0   0.709275  continuity  Evergreen
# 1   0.505221  continuity   Tomorrow
# 2   0.487205  continuity   Tomorrow
# 3   0.000000  continuity  Evergreen
# 4   0.568378  continuity  Evergreen

# %%
#reorder columns
ig = ig[['date','link','media type','caption','episode','reach','impressions','engagement','eng rate','likes','comments','vis eng','video views','view rate','phase','messaging']]

ig.head()
# Out:
#         date                                      link media type  \
# 0 2018-11-04  https://www.instagram.com/p/BpxWbo-nD85/      VIDEO
# 1 2018-11-05  https://www.instagram.com/p/Bpz6LCCHYAQ/      VIDEO
# 2 2018-11-05  https://www.instagram.com/p/BpzkKiIn4AI/      VIDEO
# 3 2018-11-06  https://www.instagram.com/p/Bp2ZojTHEVN/      IMAGE
# 4 2018-11-07  https://www.instagram.com/p/Bp2-Oiogupi/      VIDEO
#
#                                              caption episode   reach  \
# 0  If you love experimenting with edibles, then y...     204  4655.0
# 1  @EddieSteeples is up to deliver these toes to ...     204  2152.0
# 2  If Tommy told you not to party in his beach ho...     204  1825.0
# 3  Michael Cassidy sneaking up on you unexpectedl...     204  2811.0
# 4  When celebrating new shoes turns into one wild...     204  2060.0
#
#    impressions  engagement  eng rate  likes  comments  vis eng  video views  \
# 0       5046.0       131.0  0.025961  113.0       4.0    117.0       3579.0
# 1       2490.0        99.0  0.039759   88.0       6.0     94.0       1258.0
# 2       2032.0        46.0  0.022638   41.0       4.0     45.0        990.0
# 3       3165.0       119.0  0.037599  111.0       5.0    116.0          0.0
# 4       2435.0        94.0  0.038604   84.0       6.0     90.0       1384.0
#
#    view rate       phase  messaging
# 0   0.709275  continuity  Evergreen
# 1   0.505221  continuity   Tomorrow
# 2   0.487205  continuity   Tomorrow
# 3   0.000000  continuity  Evergreen
# 4   0.568378  continuity  Evergreen

# %%
#write to csv
ig.to_csv('ig_org_weekly.csv')
